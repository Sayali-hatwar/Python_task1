# %% [markdown]
# ## items()
# **Returns list containing tuples for each key value pair**

# %%
creator_analytics = {
    "profile_id": "IG_5592",
    "handle": "@coder_sayali",
    "niche": "Technology",
    "total_followers": 25000,
    "growth_rate": "15%",
    "avg_likes": 1200,
    "avg_comments": 85,
    "engagement_rate": 4.2,
    "top_countries": ["India", "USA", "UK"],
    "is_verified": False,
    "post_count": 450,
    "account_type": "Business",
    "monetized": True,
    "primary_language": "English",
    "revenue_stats": {"ad_sense": 500, "sponsorships": 1200}
}

print(f"Dictionary : {creator_analytics}")
print(f"Items of dictionary are : {creator_analytics.items()}")
# Out:
# Dictionary : {'profile_id': 'IG_5592', 'handle': '@coder_sayali', 'niche': 'Technology', 'total_followers': 25000, 'growth_rate': '15%', 'avg_likes': 1200, 'avg_comments': 85, 'engagement_rate': 4.2, 'top_countries': ['India', 'USA', 'UK'], 'is_verified': False, 'post_count': 450, 'account_type': 'Business', 'monetized': True, 'primary_language': 'English', 'revenue_stats': {'ad_sense': 500, 'sponsorships': 1200}}
# Items of dictionary are : dict_items([('profile_id', 'IG_5592'), ('handle', '@coder_sayali'), ('niche', 'Technology'), ('total_followers', 25000), ('growth_rate', '15%'), ('avg_likes', 1200), ('avg_comments', 85), ('engagement_rate', 4.2), ('top_countries', ['India', 'USA', 'UK']), ('is_verified', False), ('post_count', 450), ('account_type', 'Business'), ('monetized', True), ('primary_language', 'English'), ('revenue_stats', {'ad_sense': 500, 'sponsorships': 1200})])

# %%
medical_report = {
    "patient_id": "PAT_110",
    "full_name": "Rajiv Mehra",
    "age": 45,
    "gender": "Male",
    "blood_group": "B+",
    "weight_kg": 78.5,
    "height_cm": 175,
    "is_insured": True,
    "last_visit": "2026-02-10",
    "current_meds": ["Vitamin D", "Iron Syrup"],
    "allergies": ["Peanuts", "Dust"],
    "smoking_status": "Non-Smoker",
    "bp_systolic": 120,
    "bp_diastolic": 80,
    "vitals": {"heart_rate": 72, "temp": 98.6, "spO2": 99}
}

print(f"Dictionary : {medical_report}")
mr = medical_report.items()
print(f"Items of dictionary are : {mr}")
# Out:
# Dictionary : {'patient_id': 'PAT_110', 'full_name': 'Rajiv Mehra', 'age': 45, 'gender': 'Male', 'blood_group': 'B+', 'weight_kg': 78.5, 'height_cm': 175, 'is_insured': True, 'last_visit': '2026-02-10', 'current_meds': ['Vitamin D', 'Iron Syrup'], 'allergies': ['Peanuts', 'Dust'], 'smoking_status': 'Non-Smoker', 'bp_systolic': 120, 'bp_diastolic': 80, 'vitals': {'heart_rate': 72, 'temp': 98.6, 'spO2': 99}}
# Items of dictionary are : dict_items([('patient_id', 'PAT_110'), ('full_name', 'Rajiv Mehra'), ('age', 45), ('gender', 'Male'), ('blood_group', 'B+'), ('weight_kg', 78.5), ('height_cm', 175), ('is_insured', True), ('last_visit', '2026-02-10'), ('current_meds', ['Vitamin D', 'Iron Syrup']), ('allergies', ['Peanuts', 'Dust']), ('smoking_status', 'Non-Smoker'), ('bp_systolic', 120), ('bp_diastolic', 80), ('vitals', {'heart_rate': 72, 'temp': 98.6, 'spO2': 99})])

# %%
property_listing = {
    "listing_id": "PROP_554",
    "type": "Apartment",
    "status": "For Sale",
    "price_cr": 2.5,
    "area_sqft": 1500,
    "bedrooms": 3,
    "bathrooms": 2,
    "parking_spots": 1,
    "floor_number": 12,
    "total_floors": 20,
    "address": "Bandra West, Mumbai",
    "amenities": ["Gym", "Pool", "Clubhouse", "CCTV"],
    "is_furnished": False,
    "possession_year": 2026,
    "owner_info": {"name": "Amit Shah", "contact": "9876543210"}
}

print(f"Dictionary : {property_listing}")
pl = property_listing.items()
print(f"Items of dictionary are : {pl}")
# Out:
# Dictionary : {'listing_id': 'PROP_554', 'type': 'Apartment', 'status': 'For Sale', 'price_cr': 2.5, 'area_sqft': 1500, 'bedrooms': 3, 'bathrooms': 2, 'parking_spots': 1, 'floor_number': 12, 'total_floors': 20, 'address': 'Bandra West, Mumbai', 'amenities': ['Gym', 'Pool', 'Clubhouse', 'CCTV'], 'is_furnished': False, 'possession_year': 2026, 'owner_info': {'name': 'Amit Shah', 'contact': '9876543210'}}
# Items of dictionary are : dict_items([('listing_id', 'PROP_554'), ('type', 'Apartment'), ('status', 'For Sale'), ('price_cr', 2.5), ('area_sqft', 1500), ('bedrooms', 3), ('bathrooms', 2), ('parking_spots', 1), ('floor_number', 12), ('total_floors', 20), ('address', 'Bandra West, Mumbai'), ('amenities', ['Gym', 'Pool', 'Clubhouse', 'CCTV']), ('is_furnished', False), ('possession_year', 2026), ('owner_info', {'name': 'Amit Shah', 'contact': '9876543210'})])

# %%
product_details = {
    "product_id": "SKU-99012",
    "title": "Wireless Gaming Mouse",
    "brand": "Logitech",
    "price": 4500,
    "currency": "INR",
    "discount_pct": 10,
    "in_stock": True,
    "quantity": 45,
    "color": "Matte Black",
    "weight_grams": 85,
    "connectivity": ["Bluetooth", "USB-C", "2.4GHz Wireless"],
    "warranty_months": 24,
    "rating": 4.8,
    "reviews_count": 1250,
    "dimensions": {"length": 12.5, "width": 6.8, "height": 4.3}
}

print(f"Dictionary : {product_details}")
pd = product_details.items()
print(f"Items of dictionary are : {pd}")
print(f"length of product_details dict : {len(product_details)}")
# Out:
# Dictionary : {'product_id': 'SKU-99012', 'title': 'Wireless Gaming Mouse', 'brand': 'Logitech', 'price': 4500, 'currency': 'INR', 'discount_pct': 10, 'in_stock': True, 'quantity': 45, 'color': 'Matte Black', 'weight_grams': 85, 'connectivity': ['Bluetooth', 'USB-C', '2.4GHz Wireless'], 'warranty_months': 24, 'rating': 4.8, 'reviews_count': 1250, 'dimensions': {'length': 12.5, 'width': 6.8, 'height': 4.3}}
# Items of dictionary are : dict_items([('product_id', 'SKU-99012'), ('title', 'Wireless Gaming Mouse'), ('brand', 'Logitech'), ('price', 4500), ('currency', 'INR'), ('discount_pct', 10), ('in_stock', True), ('quantity', 45), ('color', 'Matte Black'), ('weight_grams', 85), ('connectivity', ['Bluetooth', 'USB-C', '2.4GHz Wireless']), ('warranty_months', 24), ('rating', 4.8), ('reviews_count', 1250), ('dimensions', {'length': 12.5, 'width': 6.8, 'height': 4.3})])
# length of product_details dict : 15

# %%
employee_record = {
    "emp_id": "EMP8820",
    "first_name": "Sayali",
    "last_name": "Hatwar",
    "department": "Engineering",
    "role": "Python Developer",
    "is_permanent": True,
    "salary_lpa": 12.5,
    "joining_date": "2024-01-15",
    "manager": "Rahul Sharma",
    "email": "sayali.h@company.com",
    "office_location": "Mumbai",
    "skills": ["Python", "PowerBI", "Git", "SQL"],
    "work_mode": "Hybrid",
    "performance_rating": 4.5,
    "emergency_contact": {"name": "S. Hatwar", "relation": "Brother"}
}

print(f"Dictionary : {employee_record}")
er = employee_record.items()
print(f"Items of dictionary are: {er}")
# Out:
# Dictionary : {'emp_id': 'EMP8820', 'first_name': 'Sayali', 'last_name': 'Hatwar', 'department': 'Engineering', 'role': 'Python Developer', 'is_permanent': True, 'salary_lpa': 12.5, 'joining_date': '2024-01-15', 'manager': 'Rahul Sharma', 'email': 'sayali.h@company.com', 'office_location': 'Mumbai', 'skills': ['Python', 'PowerBI', 'Git', 'SQL'], 'work_mode': 'Hybrid', 'performance_rating': 4.5, 'emergency_contact': {'name': 'S. Hatwar', 'relation': 'Brother'}}
# Items of dictionary are: dict_items([('emp_id', 'EMP8820'), ('first_name', 'Sayali'), ('last_name', 'Hatwar'), ('department', 'Engineering'), ('role', 'Python Developer'), ('is_permanent', True), ('salary_lpa', 12.5), ('joining_date', '2024-01-15'), ('manager', 'Rahul Sharma'), ('email', 'sayali.h@company.com'), ('office_location', 'Mumbai'), ('skills', ['Python', 'PowerBI', 'Git', 'SQL']), ('work_mode', 'Hybrid'), ('performance_rating', 4.5), ('emergency_contact', {'name': 'S. Hatwar', 'relation': 'Brother'})])

# %%
book = {
    "title": "Atomic Habits",
    "pages": 320,
    "author": "James Clear",
    "hardcover": False,
    "publisher": {"name": "Penguin", "city": "NYC"}
}

print(f"Dictionary : {book}")
b1 = book.items()
print(f"Items of dictionary are : {b1}")
# Out:
# Dictionary : {'title': 'Atomic Habits', 'pages': 320, 'author': 'James Clear', 'hardcover': False, 'publisher': {'name': 'Penguin', 'city': 'NYC'}}
# Items of dictionary are : dict_items([('title', 'Atomic Habits'), ('pages', 320), ('author', 'James Clear'), ('hardcover', False), ('publisher', {'name': 'Penguin', 'city': 'NYC'})])

# %%
battery_status = {
    "percentage": 85,
    "plugged_in": False,
    "health": "Good",
    "cycles": 120,
    "power_stats": {"voltage": "19V", "drain_rate": "Low"}
}

print(f"Dictionary : {battery_status}")

bs = battery_status.items()

print(f"Items of dictionary are : {bs}")
# Out:
# Dictionary : {'percentage': 85, 'plugged_in': False, 'health': 'Good', 'cycles': 120, 'power_stats': {'voltage': '19V', 'drain_rate': 'Low'}}
# Items of dictionary are : dict_items([('percentage', 85), ('plugged_in', False), ('health', 'Good'), ('cycles', 120), ('power_stats', {'voltage': '19V', 'drain_rate': 'Low'})])

# %%
pizza = {
    "name": "Margherita",
    "crust": ["Thin","Medium"],
    "veg": True,
    "price": [499,450,525],
    "toppings": {"base": "Cheese", "extra": "Basil", "sauce": "Tomato"}
}

print(f"Dictionary : {pizza}")

p1 = pizza.items()

print(f"Items of dictionary are : {p1}")
# Out:
# Dictionary : {'name': 'Margherita', 'crust': ['Thin', 'Medium'], 'veg': True, 'price': [499, 450, 525], 'toppings': {'base': 'Cheese', 'extra': 'Basil', 'sauce': 'Tomato'}}
# Items of dictionary are : dict_items([('name', 'Margherita'), ('crust', ['Thin', 'Medium']), ('veg', True), ('price', [499, 450, 525]), ('toppings', {'base': 'Cheese', 'extra': 'Basil', 'sauce': 'Tomato'})])

# %%
ticket = {
    "pnr": "XY7890",
    "seat": "12A",
    "airline": "Indigo",
    "gate": "B3",
    "route": {"from": "BOM", "to": "DEL", "duration": "2h"}
}

print(f"Dictionary : {ticket}")

tik = ticket.items()

print(f"Items of dictionary are : {tik}")
# Out:
# Dictionary : {'pnr': 'XY7890', 'seat': '12A', 'airline': 'Indigo', 'gate': 'B3', 'route': {'from': 'BOM', 'to': 'DEL', 'duration': '2h'}}
# Items of dictionary are : dict_items([('pnr', 'XY7890'), ('seat', '12A'), ('airline', 'Indigo'), ('gate', 'B3'), ('route', {'from': 'BOM', 'to': 'DEL', 'duration': '2h'})])

# %%
video = {
    "v_id": "yt_778",
    "title": "Python Tutorial",
    "views": 5000,
    "ads_enabled": True,
    "engagement": {"likes": 400, "comments": 22}
}

print(f"Dictionary : {video}")

v1 = video.items()

print(f"Items of dictionary are : {v1}")
# Out:
# Dictionary : {'v_id': 'yt_778', 'title': 'Python Tutorial', 'views': 5000, 'ads_enabled': True, 'engagement': {'likes': 400, 'comments': 22}}
# Items of dictionary are : dict_items([('v_id', 'yt_778'), ('title', 'Python Tutorial'), ('views', 5000), ('ads_enabled', True), ('engagement', {'likes': 400, 'comments': 22})])

# %%
Vacation = {
    "Name": ["Saurav","Ridhhi","Ravi","Sudhir"],
    "Plane":["Indigo","AirIndia","GSR"],
    "Seat":["R34","S4","S23","R3"],
    "Destination": "Thailand",
    "Motto": "Mind-Fresh"

}

print(f"Dictionary : {Vacation}")

Vac = Vacation.items()

print(f"Items of dictionary are : {Vac}")
# Out:
# Dictionary : {'Name': ['Saurav', 'Ridhhi', 'Ravi', 'Sudhir'], 'Plane': ['Indigo', 'AirIndia', 'GSR'], 'Seat': ['R34', 'S4', 'S23', 'R3'], 'Destination': 'Thailand', 'Motto': 'Mind-Fresh'}
# Items of dictionary are : dict_items([('Name', ['Saurav', 'Ridhhi', 'Ravi', 'Sudhir']), ('Plane', ['Indigo', 'AirIndia', 'GSR']), ('Seat', ['R34', 'S4', 'S23', 'R3']), ('Destination', 'Thailand'), ('Motto', 'Mind-Fresh')])

# %%
player_stats = {
    "id": "ShadowHunter99",
    "level": 45,
    "kills": 1200,
    "deaths": 400,
    "rank": {"current": "Platinum", "top": "Diamond", "tier": 3}
}

print(f"Dictionary : {player_stats}")

ps = player_stats.items()

print(ps)
# Out:
# Dictionary : {'id': 'ShadowHunter99', 'level': 45, 'kills': 1200, 'deaths': 400, 'rank': {'current': 'Platinum', 'top': 'Diamond', 'tier': 3}}
# dict_items([('id', 'ShadowHunter99'), ('level', 45), ('kills', 1200), ('deaths', 400), ('rank', {'current': 'Platinum', 'top': 'Diamond', 'tier': 3})])

# %%
book = {
    "title": ["Atomic Habits","We are strangers"],
    "pages": {"Atomic Habits":320,"We are strangers":250},
    "author": "James Clear","Rasha Kyrti"
    "hardcover": False,
    "publisher": {"Atomic Habits":{"name": "Penguin", "city": "NYC"}, "We are strangers":{"name":"Best friends","city":"London"}}
}

print(f"Dictionary : {book}")
bk = book.items()
print(bk)
# Out:
# Dictionary : {'title': ['Atomic Habits', 'We are strangers'], 'pages': {'Atomic Habits': 320, 'We are strangers': 250}, 'author': 'James Clear', 'Rasha Kyrtihardcover': False, 'publisher': {'Atomic Habits': {'name': 'Penguin', 'city': 'NYC'}, 'We are strangers': {'name': 'Best friends', 'city': 'London'}}}
# dict_items([('title', ['Atomic Habits', 'We are strangers']), ('pages', {'Atomic Habits': 320, 'We are strangers': 250}), ('author', 'James Clear'), ('Rasha Kyrtihardcover', False), ('publisher', {'Atomic Habits': {'name': 'Penguin', 'city': 'NYC'}, 'We are strangers': {'name': 'Best friends', 'city': 'London'}})])

# %%
# Length: 5
user_profile = {
    "username": "Sayali_H",
    "id": 4492,
    "email": "sayali@example.com",
    "joined": "March 2026",
    "is_premium": False
}

print(f"Dictionary : {user_profile}")
up = user_profile.items()
print(up)
# Out:
# Dictionary : {'username': 'Sayali_H', 'id': 4492, 'email': 'sayali@example.com', 'joined': 'March 2026', 'is_premium': False}
# dict_items([('username', 'Sayali_H'), ('id', 4492), ('email', 'sayali@example.com'), ('joined', 'March 2026'), ('is_premium', False)])

# %%
colors = {
    "red": "laal",
    "blue": "neela",
    "green": "hara",
    "yellow": "peela",
    "pink": "gulabi",
    "black": "kala",
    "Fruits":["Apple","Guava","Banana","Watermelon"]
}

print(f"Dictionary : {colors}")
cl = colors.items()
print(cl)
# Out:
# Dictionary : {'red': 'laal', 'blue': 'neela', 'green': 'hara', 'yellow': 'peela', 'pink': 'gulabi', 'black': 'kala', 'Fruits': ['Apple', 'Guava', 'Banana', 'Watermelon']}
# dict_items([('red', 'laal'), ('blue', 'neela'), ('green', 'hara'), ('yellow', 'peela'), ('pink', 'gulabi'), ('black', 'kala'), ('Fruits', ['Apple', 'Guava', 'Banana', 'Watermelon'])])
