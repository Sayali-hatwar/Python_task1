# %% [markdown]
# ## values()
# **Returns the list all the values of dictionary**
#
# **No string needed to specify**

# %%
Airline_Ticket = {
    "pnr": "XY99", 
    "from": "BOM", 
    "stops": ["DXB", "LHR"], 
    "airline": "Emirates", 
    "seat": {"row": 12, "pos": "Window"}
    }

print(f"Dictionary : {Airline_Ticket}")
print("--"*20)
at = Airline_Ticket.values()
print(f"Dictionary Values: {at}")
# Out:
# Dictionary : {'pnr': 'XY99', 'from': 'BOM', 'stops': ['DXB', 'LHR'], 'airline': 'Emirates', 'seat': {'row': 12, 'pos': 'Window'}}
# ----------------------------------------
# Dictionary Values: dict_values(['XY99', 'BOM', ['DXB', 'LHR'], 'Emirates', {'row': 12, 'pos': 'Window'}])

# %%
Music_Album = {
    "title": "Evermore", 
    "artist": "Taylor Swift", 
    "tracks": ["Willow", "Gold Rush"], 
    "year": 2020, 
    "label": {"name": "Republic"}
    }
print(f"Dictionary : {Music_Album}")
print("--"*20)
gt = Music_Album.values()  ## putting key outside of dict gives default as output 
print(f"Dictionary Values : {gt}")
# Out:
# Dictionary : {'title': 'Evermore', 'artist': 'Taylor Swift', 'tracks': ['Willow', 'Gold Rush'], 'year': 2020, 'label': {'name': 'Republic'}}
# ----------------------------------------
# Dictionary Values : dict_values(['Evermore', 'Taylor Swift', ['Willow', 'Gold Rush'], 2020, {'name': 'Republic'}])

# %%
Gym_Membership = {
    "plan": "Gold", 
    "months": 12, 
    "access": ["Yoga", "Pool", "Sauna"], 
    "active": True, 
    "trainer": {"name": "Rocky", "slot": "7 AM"}
    }
print(f"Dictionary : {Gym_Membership}")
print("--"*20)
gm = Gym_Membership.values()
print(f"Dictionary Values : {gm}")
# Out:
# Dictionary : {'plan': 'Gold', 'months': 12, 'access': ['Yoga', 'Pool', 'Sauna'], 'active': True, 'trainer': {'name': 'Rocky', 'slot': '7 AM'}}
# ----------------------------------------
# Dictionary Values : dict_values(['Gold', 12, ['Yoga', 'Pool', 'Sauna'], True, {'name': 'Rocky', 'slot': '7 AM'}])

# %%
Football_Club = {
    "name": "Real Madrid", 
    "trophies": 14, 
    "players": ["Vini", "Jude"], 
    "stadium": "Bernabeu", 
    "coach": {"name": "Carlo", "age": 64}
    }
print(f"Dictionary : {Football_Club}")
print("--"*20)
fc = Football_Club.values()
print(f"Dictionary Values : {fc}")
# Out:
# Dictionary : {'name': 'Real Madrid', 'trophies': 14, 'players': ['Vini', 'Jude'], 'stadium': 'Bernabeu', 'coach': {'name': 'Carlo', 'age': 64}}
# ----------------------------------------
# Dictionary Values : dict_values(['Real Madrid', 14, ['Vini', 'Jude'], 'Bernabeu', {'name': 'Carlo', 'age': 64}])

# %%
Theme_Park = {
    "name": "Disney", 
    "city": "Orlando", 
    "rides": ["Space Mtn", "Splash"], 
    "ticket": 150, 
    "info": {"kids_free": False, "park_id": 101}
    }
print(f"Dictionary : {Theme_Park}")
print("--"*20)
tp = Theme_Park.values()
print(f"Dictionary Values : {tp}")
# Out:
# Dictionary : {'name': 'Disney', 'city': 'Orlando', 'rides': ['Space Mtn', 'Splash'], 'ticket': 150, 'info': {'kids_free': False, 'park_id': 101}}
# ----------------------------------------
# Dictionary Values : dict_values(['Disney', 'Orlando', ['Space Mtn', 'Splash'], 150, {'kids_free': False, 'park_id': 101}])

# %%
favourites = {
    "color":"Maroon",
    "Brand":"Zudio",
    "Cloths":"Baggie",
    "Laptop":"Dell",
    "Mobile":"Readmi",
    "Vegetable":"coliflower"
}
print(f"Dictionary : {favourites}")
print("--"*20)
fv = favourites.values()
print(f"Dictionary Values : {fv}")
# Out:
# Dictionary : {'color': 'Maroon', 'Brand': 'Zudio', 'Cloths': 'Baggie', 'Laptop': 'Dell', 'Mobile': 'Readmi', 'Vegetable': 'coliflower'}
# ----------------------------------------
# Dictionary Values : dict_values(['Maroon', 'Zudio', 'Baggie', 'Dell', 'Readmi', 'coliflower'])

# %%
Fine_Dining = {
    "name": "Le Bistro", 
    "michelin_stars": 1, 
    "cuisine": "French", 
    "dress_code": "Formal", 
    "contact": {"phone": "123", "web": "lb.com"}
    }
print(f"Dictionary : {Fine_Dining}")
print("--"*20)
print(f"Dictionary Values : {Fine_Dining.values()}")
# Out:
# Dictionary : {'name': 'Le Bistro', 'michelin_stars': 1, 'cuisine': 'French', 'dress_code': 'Formal', 'contact': {'phone': '123', 'web': 'lb.com'}}
# ----------------------------------------
# Dictionary Values : dict_values(['Le Bistro', 1, 'French', 'Formal', {'phone': '123', 'web': 'lb.com'}])

# %%
Recipe_Book = {
    "title": "Spicy Pasta", 
    "time": "20min", 
    "ingredients": ["Pasta", "Chili", "Oil"], 
    "serves": 2, 
    "author": {"name": "Chef J", 
               "city": "Rome"}
               }
print(f"Dictionary : {Recipe_Book}")
print("--"*20)
print(f"Dictionary Values : {Recipe_Book.values()}")
# Out:
# Dictionary : {'title': 'Spicy Pasta', 'time': '20min', 'ingredients': ['Pasta', 'Chili', 'Oil'], 'serves': 2, 'author': {'name': 'Chef J', 'city': 'Rome'}}
# ----------------------------------------
# Dictionary Values : dict_values(['Spicy Pasta', '20min', ['Pasta', 'Chili', 'Oil'], 2, {'name': 'Chef J', 'city': 'Rome'}])

# %%
Cocktail= {
    "name": "Mojito", 
    "alcohol": "Rum", 
    "garnishes": ["Mint", "Lime"], 
    "is_cold": True, 
    "glass": {"type": "Highball", "volume": "300ml"}
    }
print(f"Dictionary : {Cocktail}")
print("--"*20)
print(f"Dictionary Values : {Cocktail.values()}")
# Out:
# Dictionary : {'name': 'Mojito', 'alcohol': 'Rum', 'garnishes': ['Mint', 'Lime'], 'is_cold': True, 'glass': {'type': 'Highball', 'volume': '300ml'}}
# ----------------------------------------
# Dictionary Values : dict_values(['Mojito', 'Rum', ['Mint', 'Lime'], True, {'type': 'Highball', 'volume': '300ml'}])

# %%
Burger_Shop = {
    "shop": "Burger King", 
    "best_seller": "Whopper", 
    "veg_options": ["Bean", "Paneer"],
      "drive_thru": True, 
      "hours": {"open": 9, "close": 23}
      }
print(f"Dictionary : {Burger_Shop}")
print("--"*20)
print(f"Dictionary Values : {Burger_Shop.values()}")
# Out:
# Dictionary : {'shop': 'Burger King', 'best_seller': 'Whopper', 'veg_options': ['Bean', 'Paneer'], 'drive_thru': True, 'hours': {'open': 9, 'close': 23}}
# ----------------------------------------
# Dictionary Values : dict_values(['Burger King', 'Whopper', ['Bean', 'Paneer'], True, {'open': 9, 'close': 23}])

# %%
School_Bus = {
    "bus_no": "MH-31-4455", 
    "driver_name": "Vijay", 
    "route_id": "R-10", 
    "student_capacity": 50, 
    "current_count": 32, 
    "fuel_level": "70%", 
    "is_gps_active": True, 
    "last_stop": "Main Gate", 
    "next_stop": "Civil Lines", 
    "speed_kmph": 40, 
    "has_camera": True, 
    "emergency_contact": "100", 
    "first_aid_expiry": "2027", 
    "attendant": "Mrs. Deshpande", 
    "engine_stats": {"temp": "Normal", 
                     "oil": "Good"}}

print(f"Dictionary : {School_Bus}")
print("--"*20)
print(f"Dictionary Values : {School_Bus.values()}")
# Out:
# Dictionary : {'bus_no': 'MH-31-4455', 'driver_name': 'Vijay', 'route_id': 'R-10', 'student_capacity': 50, 'current_count': 32, 'fuel_level': '70%', 'is_gps_active': True, 'last_stop': 'Main Gate', 'next_stop': 'Civil Lines', 'speed_kmph': 40, 'has_camera': True, 'emergency_contact': '100', 'first_aid_expiry': '2027', 'attendant': 'Mrs. Deshpande', 'engine_stats': {'temp': 'Normal', 'oil': 'Good'}}
# ----------------------------------------
# Dictionary Values : dict_values(['MH-31-4455', 'Vijay', 'R-10', 50, 32, '70%', True, 'Main Gate', 'Civil Lines', 40, True, '100', '2027', 'Mrs. Deshpande', {'temp': 'Normal', 'oil': 'Good'}])

# %%
Restaurant_Reservation = {
    "res_id": "RES-889", 
    "guest_name": "Rohan", 
    "guests_count": 4, 
    "table_no": 12, 
    "section": "Rooftop", 
    "booking_time": "08:00 PM", 
    "is_confirmed": True, 
    "phone": "9876543210", 
    "occasion": "Birthday", 
    "dietary_req": ["No Onions"], 
    "total_bill": 4500, 
    "loyalty_member": True, 
    "arrival_status": "Expected", 
    "server_assigned": "Sagar", 
    "order_pre_details": {"drinks": 4, "starters": 2}
    }
print(f"Dictionary : {Restaurant_Reservation}")
print("--"*20)
print(Restaurant_Reservation.values())
# Out:
# Dictionary : {'res_id': 'RES-889', 'guest_name': 'Rohan', 'guests_count': 4, 'table_no': 12, 'section': 'Rooftop', 'booking_time': '08:00 PM', 'is_confirmed': True, 'phone': '9876543210', 'occasion': 'Birthday', 'dietary_req': ['No Onions'], 'total_bill': 4500, 'loyalty_member': True, 'arrival_status': 'Expected', 'server_assigned': 'Sagar', 'order_pre_details': {'drinks': 4, 'starters': 2}}
# ----------------------------------------
# dict_values(['RES-889', 'Rohan', 4, 12, 'Rooftop', '08:00 PM', True, '9876543210', 'Birthday', ['No Onions'], 4500, True, 'Expected', 'Sagar', {'drinks': 4, 'starters': 2}])

# %%
YouTube_Channel = {
    "channel_name": "PythonWorld", 
    "subscribers": 50000, 
    "videos_count": 200, 
    "is_monetized": True, 
    "category": "Education",
      "join_date": "2022-01-01", 
      "avg_views": 5000, 
      "country": "India", 
      "language": "Hindi", 
      "links": ["Instagram", "Twitter"], 
      "is_verified": True, 
      "latest_video": "Loops in Python", 
      "keywords": ["Python", "Tutorial"], 
      "owner_email": "admin@pw.com", 
      "monthly_stats": {"revenue": 500, "new_subs": 1200}
      }
print(f"Dictionary : {YouTube_Channel}")
print("--"*20)
print(YouTube_Channel.values())
# Out:
# Dictionary : {'channel_name': 'PythonWorld', 'subscribers': 50000, 'videos_count': 200, 'is_monetized': True, 'category': 'Education', 'join_date': '2022-01-01', 'avg_views': 5000, 'country': 'India', 'language': 'Hindi', 'links': ['Instagram', 'Twitter'], 'is_verified': True, 'latest_video': 'Loops in Python', 'keywords': ['Python', 'Tutorial'], 'owner_email': 'admin@pw.com', 'monthly_stats': {'revenue': 500, 'new_subs': 1200}}
# ----------------------------------------
# dict_values(['PythonWorld', 50000, 200, True, 'Education', '2022-01-01', 5000, 'India', 'Hindi', ['Instagram', 'Twitter'], True, 'Loops in Python', ['Python', 'Tutorial'], 'admin@pw.com', {'revenue': 500, 'new_subs': 1200}])

# %%
Gym_Equipment = {
    "item_name": "Treadmill", 
    "brand": "FitPro", 
    "model": "X-100", 
    "max_weight_kg": 150, 
    "has_incline": True, 
    "max_speed": 18.0, 
    "display": "LED", 
    "programs_count": 12, 
    "heart_rate_sensor": True, 
    "warranty_years": 3, 
    "voltage": "220V", 
    "colors": ["Black", "Silver"], 
    "is_foldable": True, 
    "price": 45000, 
    "service_details": {"last": "Dec", "next": "June"}}

print(f"Dictionary : {Gym_Equipment}")
print("--"*20)
print(Gym_Equipment.values())
# Out:
# Dictionary : {'item_name': 'Treadmill', 'brand': 'FitPro', 'model': 'X-100', 'max_weight_kg': 150, 'has_incline': True, 'max_speed': 18.0, 'display': 'LED', 'programs_count': 12, 'heart_rate_sensor': True, 'warranty_years': 3, 'voltage': '220V', 'colors': ['Black', 'Silver'], 'is_foldable': True, 'price': 45000, 'service_details': {'last': 'Dec', 'next': 'June'}}
# ----------------------------------------
# dict_values(['Treadmill', 'FitPro', 'X-100', 150, True, 18.0, 'LED', 12, True, 3, '220V', ['Black', 'Silver'], True, 45000, {'last': 'Dec', 'next': 'June'}])

# %%
Mobile_Phone_Order = {
    "order_id": "MO-1122", 
    "customer": "Priya", 
    "model": "iPhone 15", 
    "color": "Blue", 
    "storage": "128GB", 
    "price": 79000, 
    "is_gift": True, 
    "delivery_type": "Express", 
    "status": "Shipped", 
    "payment_method": "UPI", 
    "eta": "Tomorrow", 
    "warehouse": "Mumbai-1", 
    "accessories": ["Case", "Charger"], 
    "serial_no": "XYZ990", 
    "tracking": {"carrier": "Delhivery", "id": "990022"}
    }

print(f"Dictionary : {Mobile_Phone_Order}")
print("--"*20)
print(Mobile_Phone_Order.values())
# Out:
# Dictionary : {'order_id': 'MO-1122', 'customer': 'Priya', 'model': 'iPhone 15', 'color': 'Blue', 'storage': '128GB', 'price': 79000, 'is_gift': True, 'delivery_type': 'Express', 'status': 'Shipped', 'payment_method': 'UPI', 'eta': 'Tomorrow', 'warehouse': 'Mumbai-1', 'accessories': ['Case', 'Charger'], 'serial_no': 'XYZ990', 'tracking': {'carrier': 'Delhivery', 'id': '990022'}}
# ----------------------------------------
# dict_values(['MO-1122', 'Priya', 'iPhone 15', 'Blue', '128GB', 79000, True, 'Express', 'Shipped', 'UPI', 'Tomorrow', 'Mumbai-1', ['Case', 'Charger'], 'XYZ990', {'carrier': 'Delhivery', 'id': '990022'}])
