# %% [markdown]
# ## Copy()
# **Returns the copy of dictionary**

# %%
d1 = {"username":"Sayali",
      "email":"sayali@gmail.com",
      "age": 26,
      "Place":"Kulu-Manali",
      "Hobbie":["Dance","Reading","Sports","Music"],
      "DOB":"3/03/2002"}

print(f"Dictionary : {d1}")
print("--"*30)
l1 = d1.copy()
print(f"l1 after copying: {l1}")
print(f"type of l1 : {type(l1)}")
# Out:
# Dictionary : {'username': 'Sayali', 'email': 'sayali@gmail.com', 'age': 26, 'Place': 'Kulu-Manali', 'Hobbie': ['Dance', 'Reading', 'Sports', 'Music'], 'DOB': '3/03/2002'}
# ------------------------------------------------------------
# l1 after copying: {'username': 'Sayali', 'email': 'sayali@gmail.com', 'age': 26, 'Place': 'Kulu-Manali', 'Hobbie': ['Dance', 'Reading', 'Sports', 'Music'], 'DOB': '3/03/2002'}
# type of l1 : <class 'dict'>

# %%
d2 = {"Game":["Badminton","Cricket","Volleyball","Football"],
      "Team":["Team1","Team2","Team3","Team4"],
      "age_category": "Under_21",
      "Place":"Delhi",
      "Players":["Bombay_hippie","Royals_roy","Diggu_picku","Surya_tamator"],
      "No_player":"50"}

print(f"Dictionary : {d2}")
print("--"*20)
l2 = d2.copy()
print(f"l2 after copying :{l2}")
print(f"type of l2 : {type(l2)}")
# Out:
# Dictionary : {'Game': ['Badminton', 'Cricket', 'Volleyball', 'Football'], 'Team': ['Team1', 'Team2', 'Team3', 'Team4'], 'age_category': 'Under_21', 'Place': 'Delhi', 'Players': ['Bombay_hippie', 'Royals_roy', 'Diggu_picku', 'Surya_tamator'], 'No_player': '50'}
# ----------------------------------------
# l2 after copying :{'Game': ['Badminton', 'Cricket', 'Volleyball', 'Football'], 'Team': ['Team1', 'Team2', 'Team3', 'Team4'], 'age_category': 'Under_21', 'Place': 'Delhi', 'Players': ['Bombay_hippie', 'Royals_roy', 'Diggu_picku', 'Surya_tamator'], 'No_player': '50'}
# type of l2 : <class 'dict'>

# %%
d3 = {"type": "dictionary",
      "method":["clear","get","copy","pop","update"],
      "toy":["toy1","toy2","toy3","toy4","toy5"],
      "df":{"list":"Mutable","Dictionary":"Mutable","Set":"Mutable","Tuple":"Immutable"},
      "food": ['Chinese',"Panipuri","Bitballs","Sandwitch"],
      "drink": "coke"
      }
print(f"Dictionary : {d3}")
print("--"*20)
l3 = d3.copy()
print(f"l3 after copying :{l3}")
print(f"type of l3 : {type(l3)}")
# Out:
# Dictionary : {'type': 'dictionary', 'method': ['clear', 'get', 'copy', 'pop', 'update'], 'toy': ['toy1', 'toy2', 'toy3', 'toy4', 'toy5'], 'df': {'list': 'Mutable', 'Dictionary': 'Mutable', 'Set': 'Mutable', 'Tuple': 'Immutable'}, 'food': ['Chinese', 'Panipuri', 'Bitballs', 'Sandwitch'], 'drink': 'coke'}
# ----------------------------------------
# l3 after copying :{'type': 'dictionary', 'method': ['clear', 'get', 'copy', 'pop', 'update'], 'toy': ['toy1', 'toy2', 'toy3', 'toy4', 'toy5'], 'df': {'list': 'Mutable', 'Dictionary': 'Mutable', 'Set': 'Mutable', 'Tuple': 'Immutable'}, 'food': ['Chinese', 'Panipuri', 'Bitballs', 'Sandwitch'], 'drink': 'coke'}
# type of l3 : <class 'dict'>

# %%
product = {
    "name": {"Laptop":["HP","Dell"],"Mobile":["Readmi","Apple"],"TV":["Samsung","BPL"]},
    "price": ["75000.00","80000.00","250000.00"],
    "brand": ["HP","Dell","Apple"],
    "in_stock": True,
    "Shipped": True
}

print(f"Dictionary : {product}")
print("--"*20)
l4 = product.copy()
print(f"l4 after copying :{l4}")
print(f"type of l4 : {type(l4)}")
# Out:
# Dictionary : {'name': {'Laptop': ['HP', 'Dell'], 'Mobile': ['Readmi', 'Apple'], 'TV': ['Samsung', 'BPL']}, 'price': ['75000.00', '80000.00', '250000.00'], 'brand': ['HP', 'Dell', 'Apple'], 'in_stock': True, 'Shipped': True}
# ----------------------------------------
# l4 after copying :{'name': {'Laptop': ['HP', 'Dell'], 'Mobile': ['Readmi', 'Apple'], 'TV': ['Samsung', 'BPL']}, 'price': ['75000.00', '80000.00', '250000.00'], 'brand': ['HP', 'Dell', 'Apple'], 'in_stock': True, 'Shipped': True}
# type of l4 : <class 'dict'>

# %%
grades = {"subject": ["Math","Physics","Python","History"],
    "Math": 95,
    "Physics": 88,
    "Python": 100,
    "History": 75
}

print(f"Dictionary : {grades}")
print("--"*20)
l5 = grades.copy()
print(f"l5 after copy method : {l5}")
print(f"type of l5 : {type(l5)}")
# Out:
# Dictionary : {'subject': ['Math', 'Physics', 'Python', 'History'], 'Math': 95, 'Physics': 88, 'Python': 100, 'History': 75}
# ----------------------------------------
# l5 after copy method : {'subject': ['Math', 'Physics', 'Python', 'History'], 'Math': 95, 'Physics': 88, 'Python': 100, 'History': 75}
# type of l5 : <class 'dict'>

# %%
Student_report = {
"Name":{"Rashi":"1st std", "Umeed": "5th std","Kashish":"2nd std","Vashish":"4th std"},
"Rashi_score": {"Maths":90,"Science":95,"English":80, "Envi":100},
"Umeed_score": {"Maths":99,"Science":95,"English":90, "Envi":99},
"Kashish_score": {"Maths":85,"Science":90,"English":86, "Envi":96},
"Vashish_score": {"Maths":96,"Science":96,"English":85, "Envi":100},
}

print(f"Dictionary: {Student_report}")
print("--"*20)

l6 = Student_report.copy()
print(f" l6 after copy method : {l6}")
print(f"type of l6 : {type(l6)}")
# Out:
# Dictionary: {'Name': {'Rashi': '1st std', 'Umeed': '5th std', 'Kashish': '2nd std', 'Vashish': '4th std'}, 'Rashi_score': {'Maths': 90, 'Science': 95, 'English': 80, 'Envi': 100}, 'Umeed_score': {'Maths': 99, 'Science': 95, 'English': 90, 'Envi': 99}, 'Kashish_score': {'Maths': 85, 'Science': 90, 'English': 86, 'Envi': 96}, 'Vashish_score': {'Maths': 96, 'Science': 96, 'English': 85, 'Envi': 100}}
# ----------------------------------------
#  l6 after copy method : {'Name': {'Rashi': '1st std', 'Umeed': '5th std', 'Kashish': '2nd std', 'Vashish': '4th std'}, 'Rashi_score': {'Maths': 90, 'Science': 95, 'English': 80, 'Envi': 100}, 'Umeed_score': {'Maths': 99, 'Science': 95, 'English': 90, 'Envi': 99}, 'Kashish_score': {'Maths': 85, 'Science': 90, 'English': 86, 'Envi': 96}, 'Vashish_score': {'Maths': 96, 'Science': 96, 'English': 85, 'Envi': 100}}
# type of l6 : <class 'dict'>

# %%
course = {
    "title": "Python Programming",
    "students": ["Rahul", "Sayali", "Amit", "Priya","Sulochana"],
    "duration_months": 3,
    "duration_complete":2,
    "Course_complete":["Excel","SQL"],
    "Batch":"DA25"
}
print(f"Dictionary : {course}")
print("--"*20)
l7 = course.copy()
print(f"l7 after copy method : {l7}")
print(f"type of l7 : {type(l7)}")
# Out:
# Dictionary : {'title': 'Python Programming', 'students': ['Rahul', 'Sayali', 'Amit', 'Priya', 'Sulochana'], 'duration_months': 3, 'duration_complete': 2, 'Course_complete': ['Excel', 'SQL'], 'Batch': 'DA25'}
# ----------------------------------------
# l7 after copy method : {'title': 'Python Programming', 'students': ['Rahul', 'Sayali', 'Amit', 'Priya', 'Sulochana'], 'duration_months': 3, 'duration_complete': 2, 'Course_complete': ['Excel', 'SQL'], 'Batch': 'DA25'}
# type of l7 : <class 'dict'>

# %%
colors = {
    "red": "laal",
    "blue": "neela",
    "green": "hara",
    "yellow": "peela",
    "Brown": "Kathiya",
    "Pink": "Gulabi"
}
print(f"Dictionary : {colors}")
print("--"*20)
l8 = colors.copy()
print(f"l8 after copy method : {l8}")
print(f"type of l8 : {type(l8)}")
# Out:
# Dictionary : {'red': 'laal', 'blue': 'neela', 'green': 'hara', 'yellow': 'peela', 'Brown': 'Kathiya', 'Pink': 'Gulabi'}
# ----------------------------------------
# l8 after copy method : {'red': 'laal', 'blue': 'neela', 'green': 'hara', 'yellow': 'peela', 'Brown': 'Kathiya', 'Pink': 'Gulabi'}
# type of l8 : <class 'dict'>

# %%
settings = {
    "theme": "dark",
    "font_size": 14,
    "show_notifications": False,
    "font_color":"White-Black",
    "Apps":"VsCode",
    "Bluetooth":"ON",
    "Hotspot":"OFF"
}

print(f"Dictionary : {settings}")
print("--"*20)
l9 = settings.copy()
print(f"Dictionary after clear : {l9}")
print(f"type of l9 : {type(l9)}")
# Out:
# Dictionary : {'theme': 'dark', 'font_size': 14, 'show_notifications': False, 'font_color': 'White-Black', 'Apps': 'VsCode', 'Bluetooth': 'ON', 'Hotspot': 'OFF'}
# ----------------------------------------
# Dictionary after clear : {'theme': 'dark', 'font_size': 14, 'show_notifications': False, 'font_color': 'White-Black', 'Apps': 'VsCode', 'Bluetooth': 'ON', 'Hotspot': 'OFF'}
# type of l9 : <class 'dict'>

# %%
location = {
    "city": "Mumbai",
    "lat": 19.0760,
    "lon": 72.8777,
    "temp":42,
    "Beach": "Yes",
    "Population": 34590000,
    "Blocks":["North","south","East","West"]
}

print(f"Dictionary : {location}")
print("--"*20)
df = location.copy()
print(f"Dictionary after clear : {df}")
print(f"type of df : {type(df)}")
# Out:
# Dictionary : {'city': 'Mumbai', 'lat': 19.076, 'lon': 72.8777, 'temp': 42, 'Beach': 'Yes', 'Population': 34590000, 'Blocks': ['North', 'south', 'East', 'West']}
# ----------------------------------------
# Dictionary after clear : {'city': 'Mumbai', 'lat': 19.076, 'lon': 72.8777, 'temp': 42, 'Beach': 'Yes', 'Population': 34590000, 'Blocks': ['North', 'south', 'East', 'West']}
# type of df : <class 'dict'>

# %%
Post = {
    "author_handle": "@python_coder",
    "content": "Learning Git today!",
    "timestamp": "2024-05-20",
    "tags": ["coding", "git", "python"],
    "is_public": True,
    "likes_count": 120,
    "Platform":["Git","Linkedin"],
    "Topic":"Use of dictionary and it's methods",
    "DeviceUsed": "Laptop",
    "Slides":3,
    "Languages":'English',
    "author_stats": {
        "followers": 500,
        "following": 250,
        "verified": False,
        "bio": "Keep Coding",
        "top_skills": ["Python", "CLI", "VSCode"]
    }
}
print(f"Dictionary : {Post}")
print("--"*20)
pf = Post.copy()
print(f"Dictionary after clear : {pf}")
print(f"type of df : {type(pf)}")
# Out:
# Dictionary : {'author_handle': '@python_coder', 'content': 'Learning Git today!', 'timestamp': '2024-05-20', 'tags': ['coding', 'git', 'python'], 'is_public': True, 'likes_count': 120, 'Platform': ['Git', 'Linkedin'], 'Topic': "Use of dictionary and it's methods", 'DeviceUsed': 'Laptop', 'Slides': 3, 'Languages': 'English', 'author_stats': {'followers': 500, 'following': 250, 'verified': False, 'bio': 'Keep Coding', 'top_skills': ['Python', 'CLI', 'VSCode']}}
# ----------------------------------------
# Dictionary after clear : {'author_handle': '@python_coder', 'content': 'Learning Git today!', 'timestamp': '2024-05-20', 'tags': ['coding', 'git', 'python'], 'is_public': True, 'likes_count': 120, 'Platform': ['Git', 'Linkedin'], 'Topic': "Use of dictionary and it's methods", 'DeviceUsed': 'Laptop', 'Slides': 3, 'Languages': 'English', 'author_stats': {'followers': 500, 'following': 250, 'verified': False, 'bio': 'Keep Coding', 'top_skills': ['Python', 'CLI', 'VSCode']}}
# ...

# %%
employees = {
    "emp1": {"name": "Alice", "role": "Developer"},
    "emp2": {"name": "Bob", "role": "Designer"},
    "emp3": {"name":"Stuart","role":"Analyst"},
    "emp4": {"name":"Alok","role":"Analyst"},
    "emp5": {"name":"Sam","role":"Engineer"},
    "emp6": {"name":"Juan","role":"Data Scientist"},
    "emp7": {"name":"Yan Li","role":"AI/ML"},
    "emp8": {"name":"John","role":"Developer"},
    "emp9": {"name":"Shubham","role":"Manager"},
    "emp10": {"name":"Shyam","role":"HR"},
    "emp11": {"name":"Rashika","role":"Assistant-Engineer"},
    "emp12": {"name":"Humeen","role":"Analyst"},
    "emp15": {"name":"Goldie","role":"Senior Analyst"},
    "emp16": {"name":"Barkha","role":"Backend"},
    "emp17": {"name":"Naseer","role":"Intern Devops"},

}

print(f"Dictionary : {employees}")
print("--"*20)
gf = employees.copy()
print(f"Dictionary after clear : {gf}")
print(f"type of df : {type(gf)}")
# Out:
# Dictionary : {'emp1': {'name': 'Alice', 'role': 'Developer'}, 'emp2': {'name': 'Bob', 'role': 'Designer'}, 'emp3': {'name': 'Stuart', 'role': 'Analyst'}, 'emp4': {'name': 'Alok', 'role': 'Analyst'}, 'emp5': {'name': 'Sam', 'role': 'Engineer'}, 'emp6': {'name': 'Juan', 'role': 'Data Scientist'}, 'emp7': {'name': 'Yan Li', 'role': 'AI/ML'}, 'emp8': {'name': 'John', 'role': 'Developer'}, 'emp9': {'name': 'Shubham', 'role': 'Manager'}, 'emp10': {'name': 'Shyam', 'role': 'HR'}, 'emp11': {'name': 'Rashika', 'role': 'Assistant-Engineer'}, 'emp12': {'name': 'Humeen', 'role': 'Analyst'}, 'emp15': {'name': 'Goldie', 'role': 'Senior Analyst'}, 'emp16': {'name': 'Barkha', 'role': 'Backend'}, 'emp17': {'name': 'Naseer', 'role': 'Intern Devops'}}
# ----------------------------------------
# ...

# %%
smart_home = {
    "home_id": "SH-9921",                
    "owner": "Sayali",                    
    "room_count": 5,                      
    "wifi_status": "Connected",           
    "devices": ["Light", "AC", "TV"],     
    "is_secure": True,                    
    "temperature": 22.5,                  
    "address": "Street 10, Mumbai",       
    "firmware": "v2.0.4",                 
    "security_log": {                     
        "last_login": "10:00 AM",
        "attempt_count": 0,
        "status": "Healthy",
        "location": "Main Entrance",
        "sensors": ["Motion", "Door"]      
    }
}

print(f"Dictionary : {smart_home}")
print("--"*20)
sh = smart_home.copy()
print(f"Dictionary after copying : {sh}") 
print(f"type of sh : {type(sh)}")
# Out:
# Dictionary : {'home_id': 'SH-9921', 'owner': 'Sayali', 'room_count': 5, 'wifi_status': 'Connected', 'devices': ['Light', 'AC', 'TV'], 'is_secure': True, 'temperature': 22.5, 'address': 'Street 10, Mumbai', 'firmware': 'v2.0.4', 'security_log': {'last_login': '10:00 AM', 'attempt_count': 0, 'status': 'Healthy', 'location': 'Main Entrance', 'sensors': ['Motion', 'Door']}}
# ----------------------------------------
# Dictionary after copying : {'home_id': 'SH-9921', 'owner': 'Sayali', 'room_count': 5, 'wifi_status': 'Connected', 'devices': ['Light', 'AC', 'TV'], 'is_secure': True, 'temperature': 22.5, 'address': 'Street 10, Mumbai', 'firmware': 'v2.0.4', 'security_log': {'last_login': '10:00 AM', 'attempt_count': 0, 'status': 'Healthy', 'location': 'Main Entrance', 'sensors': ['Motion', 'Door']}}
# type of sh : <class 'dict'>

# %%
order_data = {
    "order_no": "AR1001",
    "customer_name": "Rajiv Kumar",
    "payment_method": "Credit Card",
    "currency": "INR",
    "item_list": ["Phone Case", "Glass"],
    "shipping_status": "In Transit",
    "delivery_city": "Nagpur",
    "discount_code": "WELCOME10",
    "tracking_id": "TRACK_772",
    "items_details": {
        "item_1": {"qty": 1, "price": 500},
        "item_2": {"qty": 2, "price": 200},
        "total_tax": 50,
        "warehouse": "Zone A",
        "category": "Mobile Acc"
    }
}

print(f"Dictionary : {order_data}")
print("--"*20)
od = order_data.copy()
print(f"Dictionary after copying : {od}")
print(f"type of od : {type(od)}")
# Out:
# Dictionary : {'order_no': 'AR1001', 'customer_name': 'Rajiv Kumar', 'payment_method': 'Credit Card', 'currency': 'INR', 'item_list': ['Phone Case', 'Glass'], 'shipping_status': 'In Transit', 'delivery_city': 'Nagpur', 'discount_code': 'WELCOME10', 'tracking_id': 'TRACK_772', 'items_details': {'item_1': {'qty': 1, 'price': 500}, 'item_2': {'qty': 2, 'price': 200}, 'total_tax': 50, 'warehouse': 'Zone A', 'category': 'Mobile Acc'}}
# ----------------------------------------
# Dictionary after copying : {'order_no': 'AR1001', 'customer_name': 'Rajiv Kumar', 'payment_method': 'Credit Card', 'currency': 'INR', 'item_list': ['Phone Case', 'Glass'], 'shipping_status': 'In Transit', 'delivery_city': 'Nagpur', 'discount_code': 'WELCOME10', 'tracking_id': 'TRACK_772', 'items_details': {'item_1': {'qty': 1, 'price': 500}, 'item_2': {'qty': 2, 'price': 200}, 'total_tax': 50, 'warehouse': 'Zone A', 'category': 'Mobile Acc'}}
# type of od : <class 'dict'>

# %%
Car = {
    "Purchase_no": "VN39503",
    "Brand": "Toyota",
    "Model": "Fortuner",
    "year":2024,
    "features" : [4*4,"sunroof","ABS"],
    "fuel_type": "Diesel",
    "color": "Pearl White",
    "mileage": "15 kmpl",
    "insurance_id": "INS-882",
    "Inside_feature" : {
        "seats": 5,
        "Handling": ["Automatic","gear"]
    },
    "engine_specs": {
        "cylinders": 4,
        "horsepower": 201,
        "torque": "500Nm",
        "turbo": True,
        "parts": ["Piston", "Valve", "Chain"]
    }

}

print(f"Dictionary : {Car}")
print("--"*20)
Car_copy = Car.copy()
print(f"Dictionary after copying : {Car_copy}")
print(f"type of Car_copy : {type(Car_copy)}")
# Out:
# Dictionary : {'Purchase_no': 'VN39503', 'Brand': 'Toyota', 'Model': 'Fortuner', 'year': 2024, 'features': [16, 'sunroof', 'ABS'], 'fuel_type': 'Diesel', 'color': 'Pearl White', 'mileage': '15 kmpl', 'insurance_id': 'INS-882', 'Inside_feature': {'seats': 5, 'Handling': ['Automatic', 'gear']}, 'engine_specs': {'cylinders': 4, 'horsepower': 201, 'torque': '500Nm', 'turbo': True, 'parts': ['Piston', 'Valve', 'Chain']}}
# ----------------------------------------
# Dictionary after copying : {'Purchase_no': 'VN39503', 'Brand': 'Toyota', 'Model': 'Fortuner', 'year': 2024, 'features': [16, 'sunroof', 'ABS'], 'fuel_type': 'Diesel', 'color': 'Pearl White', 'mileage': '15 kmpl', 'insurance_id': 'INS-882', 'Inside_feature': {'seats': 5, 'Handling': ['Automatic', 'gear']}, 'engine_specs': {'cylinders': 4, 'horsepower': 201, 'torque': '500Nm', 'turbo': True, 'parts': ['Piston', 'Valve', 'Chain']}}
# type of Car_copy : <class 'dict'>
