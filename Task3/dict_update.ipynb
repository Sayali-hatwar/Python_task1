# %% [markdown]
# ## update()
# **Updates the dictionary with the specified key-value pairs**
#
# **.update() method is designed to be in-place. This means it changes the dictionary you already have rather than creating a new one.**

# %%
employee_detail = {
    "Id": "34853",
    "Name": "Sameer Barde",
    "email": ["sam.bar@yahoo.com","bardesameer@gamil.com"],
    "Department":"Analysis",
    "Role": "Quality Analysis",
    "Team volume": 8,
    "Manager":"Parul Bera",
    "TeamMates":["Sahil Kar","Pratham Hojiya","Renuka Rane","Tina sandel","Nihal Gurung"],
    "Floor": 4,
    "Shift":{"Night_shift":4.30, "Day_shift": 10.30},
    "Comapany": "Eclerx",
    "Size_company": 300,
    "Address": "Hinjewadi, Pune",
    "PinCode": 45444
}


print(f"Dictionary : {employee_detail}")
print("--"*30)
employee_detail.update({"Building":"Block A"})
#print(employee_detail.update({"Building":"Block A"}))
print(f"Updated dictionary : {employee_detail}")
# Out:
# Dictionary : {'Id': '34853', 'Name': 'Sameer Barde', 'email': ['sam.bar@yahoo.com', 'bardesameer@gamil.com'], 'Department': 'Analysis', 'Role': 'Quality Analysis', 'Team volume': 8, 'Manager': 'Parul Bera', 'TeamMates': ['Sahil Kar', 'Pratham Hojiya', 'Renuka Rane', 'Tina sandel', 'Nihal Gurung'], 'Floor': 4, 'Shift': {'Night_shift': 4.3, 'Day_shift': 10.3}, 'Comapany': 'Eclerx', 'Size_company': 300, 'Address': 'Hinjewadi, Pune', 'PinCode': 45444}
# ------------------------------------------------------------
# Updated value is : {'Id': '34853', 'Name': 'Sameer Barde', 'email': ['sam.bar@yahoo.com', 'bardesameer@gamil.com'], 'Department': 'Analysis', 'Role': 'Quality Analysis', 'Team volume': 8, 'Manager': 'Parul Bera', 'TeamMates': ['Sahil Kar', 'Pratham Hojiya', 'Renuka Rane', 'Tina sandel', 'Nihal Gurung'], 'Floor': 4, 'Shift': {'Night_shift': 4.3, 'Day_shift': 10.3}, 'Comapany': 'Eclerx', 'Size_company': 300, 'Address': 'Hinjewadi, Pune', 'PinCode': 45444, 'Building': 'Block A'}

# %%
creator_analytics = {
    "profile_id": "IG_5592",
    "handle": "@coder_sayali",
    "niche": "Technology",
    "total_followers": 25000,
    "growth_rate": "15%",
    "avg_likes": 1200,
    "avg_comments": 85,
    "engagement_rate": 4.2,
    "top_countries": ["India", "USA", "UK"],
    "is_verified": False,
    "post_count": 450,
    "account_type": "Business",
    "monetized": True,
    "primary_language": "English",
    "revenue_stats": {"ad_sense": 500, "sponsorships": 1200}
}

print(f"Dictionary : {creator_analytics}")
print("--"*30)
creator_analytics.update({"platform":"GitHub"})
print(f"Updated dictionary : {creator_analytics}")
# Out:
# Dictionary : {'profile_id': 'IG_5592', 'handle': '@coder_sayali', 'niche': 'Technology', 'total_followers': 25000, 'growth_rate': '15%', 'avg_likes': 1200, 'avg_comments': 85, 'engagement_rate': 4.2, 'top_countries': ['India', 'USA', 'UK'], 'is_verified': False, 'post_count': 450, 'account_type': 'Business', 'monetized': True, 'primary_language': 'English', 'revenue_stats': {'ad_sense': 500, 'sponsorships': 1200}}
# ------------------------------------------------------------
# Updated value is : {'profile_id': 'IG_5592', 'handle': '@coder_sayali', 'niche': 'Technology', 'total_followers': 25000, 'growth_rate': '15%', 'avg_likes': 1200, 'avg_comments': 85, 'engagement_rate': 4.2, 'top_countries': ['India', 'USA', 'UK'], 'is_verified': False, 'post_count': 450, 'account_type': 'Business', 'monetized': True, 'primary_language': 'English', 'revenue_stats': {'ad_sense': 500, 'sponsorships': 1200}, 'platform': 'GitHub'}

# %%
order_data = {
    "order_no": "ORD_101",
    "customer_name": "Rajiv Kumar",
    "payment_method": "Credit Card",
    "currency": "INR",
    "item_list": ["Phone Case", "Glass"],
    "shipping_status": "In Transit",
    "delivery_city": "Nagpur",
    "discount_code": "WELCOME10",
    "tracking_id": "TRACK_772",
    "items_details": {
        "item_1": {"qty": 1, "price": 500},
        "item_2": {"qty": 2, "price": 200},
        "total_tax": 50,
        "warehouse": "Zone A",
        "category": "Mobile Acc"
    }
}

print(f"Dictionary : {order_data}")
print("--"*30)
order_data.update({"Late Shipment":["Wood","Decor"]})
print(f"Updated dictionary : {order_data}")
# Out:
# Dictionary : {'order_no': 'ORD_101', 'customer_name': 'Rajiv Kumar', 'payment_method': 'Credit Card', 'currency': 'INR', 'item_list': ['Phone Case', 'Glass'], 'shipping_status': 'In Transit', 'delivery_city': 'Nagpur', 'discount_code': 'WELCOME10', 'tracking_id': 'TRACK_772', 'items_details': {'item_1': {'qty': 1, 'price': 500}, 'item_2': {'qty': 2, 'price': 200}, 'total_tax': 50, 'warehouse': 'Zone A', 'category': 'Mobile Acc'}}
# ------------------------------------------------------------
# Removed value is : {'order_no': 'ORD_101', 'customer_name': 'Rajiv Kumar', 'payment_method': 'Credit Card', 'currency': 'INR', 'item_list': ['Phone Case', 'Glass'], 'shipping_status': 'In Transit', 'delivery_city': 'Nagpur', 'discount_code': 'WELCOME10', 'tracking_id': 'TRACK_772', 'items_details': {'item_1': {'qty': 1, 'price': 500}, 'item_2': {'qty': 2, 'price': 200}, 'total_tax': 50, 'warehouse': 'Zone A', 'category': 'Mobile Acc'}, 'Late Shipment': ['Wood', 'Decor']}

# %%
product_details = {
    "product_id": "SKU-99012",
    "title": "Wireless Gaming Mouse",
    "brand": "Logitech",
    "price": 4500,
    "currency": "INR",
    "discount_pct": 10,
    "in_stock": True,
    "quantity": 45,
    "color": "Matte Black",
    "weight_grams": 85,
    "connectivity": ["Bluetooth", "USB-C", "2.4GHz Wireless"],
    "warranty_months": 24,
    "rating": 4.8,
    "reviews_count": 1250,
    "dimensions": {"length": 12.5, "width": 6.8, "height": 4.3}
}

print(f"Dictionary : {product_details}")
print("--"*30)
product_details.update({"Color":"Black"})
print(f"Updated dictionary : {product_details}")
# Out:
# Dictionary : {'product_id': 'SKU-99012', 'title': 'Wireless Gaming Mouse', 'brand': 'Logitech', 'price': 4500, 'currency': 'INR', 'discount_pct': 10, 'in_stock': True, 'quantity': 45, 'color': 'Matte Black', 'weight_grams': 85, 'connectivity': ['Bluetooth', 'USB-C', '2.4GHz Wireless'], 'warranty_months': 24, 'rating': 4.8, 'reviews_count': 1250, 'dimensions': {'length': 12.5, 'width': 6.8, 'height': 4.3}}
# ------------------------------------------------------------
# Updated dictionary : {'product_id': 'SKU-99012', 'title': 'Wireless Gaming Mouse', 'brand': 'Logitech', 'price': 4500, 'currency': 'INR', 'discount_pct': 10, 'in_stock': True, 'quantity': 45, 'color': 'Matte Black', 'weight_grams': 85, 'connectivity': ['Bluetooth', 'USB-C', '2.4GHz Wireless'], 'warranty_months': 24, 'rating': 4.8, 'reviews_count': 1250, 'dimensions': {'length': 12.5, 'width': 6.8, 'height': 4.3}, 'Color': 'Black'}

# %%
medical_report = {
    "patient_id": "PAT_110",
    "full_name": "Rajiv Mehra",
    "age": 45,
    "gender": "Male",
    "blood_group": "B+",
    "weight_kg": 78.5,
    "height_cm": 175,
    "is_insured": True,
    "last_visit": "2026-02-10",
    "current_meds": ["Vitamin D", "Iron Syrup"],
    "allergies": ["Peanuts", "Dust"],
    "smoking_status": "Non-Smoker",
    "bp_systolic": 120,
    "bp_diastolic": 80,
    "vitals": {"heart_rate": 72, "temp": 98.6, "spO2": 99}
}
print(f"Dictionary : {medical_report}")
print("--"*30)
medical_report.update({"Healthy":"Yes"})
print(f"Updated dictionary : {medical_report}")
# Out:
# Dictionary : {'patient_id': 'PAT_110', 'full_name': 'Rajiv Mehra', 'age': 45, 'gender': 'Male', 'blood_group': 'B+', 'weight_kg': 78.5, 'height_cm': 175, 'is_insured': True, 'last_visit': '2026-02-10', 'current_meds': ['Vitamin D', 'Iron Syrup'], 'allergies': ['Peanuts', 'Dust'], 'smoking_status': 'Non-Smoker', 'bp_systolic': 120, 'bp_diastolic': 80, 'vitals': {'heart_rate': 72, 'temp': 98.6, 'spO2': 99}}
# ------------------------------------------------------------
# Updated dictionary : {'patient_id': 'PAT_110', 'full_name': 'Rajiv Mehra', 'age': 45, 'gender': 'Male', 'blood_group': 'B+', 'weight_kg': 78.5, 'height_cm': 175, 'is_insured': True, 'last_visit': '2026-02-10', 'current_meds': ['Vitamin D', 'Iron Syrup'], 'allergies': ['Peanuts', 'Dust'], 'smoking_status': 'Non-Smoker', 'bp_systolic': 120, 'bp_diastolic': 80, 'vitals': {'heart_rate': 72, 'temp': 98.6, 'spO2': 99}, 'Healthy': 'Yes'}

# %%
Passport = {
    "number": "Z123",
"country": "India", 
"visas": ["USA", "UK", "UAE"], 
"expiry": 2030, 
"details": {"height": "165cm", "eyes": "Brown"}}

print(f"Dictionary : {medical_report}")
print("--"*30)
Passport.update({"Stay duration":"6 months"})
print(f"Updated dictionary :{Passport}")
# Out:
# Dictionary : {'patient_id': 'PAT_110', 'full_name': 'Rajiv Mehra', 'age': 45, 'gender': 'Male', 'blood_group': 'B+', 'weight_kg': 78.5, 'height_cm': 175, 'is_insured': True, 'last_visit': '2026-02-10', 'current_meds': ['Vitamin D', 'Iron Syrup'], 'allergies': ['Peanuts', 'Dust'], 'smoking_status': 'Non-Smoker', 'bp_systolic': 120, 'bp_diastolic': 80, 'vitals': {'heart_rate': 72, 'temp': 98.6, 'spO2': 99}, 'Healthy': 'Yes'}
# ------------------------------------------------------------
# Updated dictionary :{'number': 'Z123', 'country': 'India', 'visas': ['USA', 'UK', 'UAE'], 'expiry': 2030, 'details': {'height': '165cm', 'eyes': 'Brown'}, 'Stay duration': '6 months'}

# %%
Hiking_Trip = {
    "location": "Himalayas", 
    "difficulty": "Hard", 
    "gear": ["Boots", "Stick"], 
    "days": 5, 
    "guide": {"name": "Sherpa", "exp": "20y"}
    }

print(f"Dictionary : {Hiking_Trip}")
print("--"*30)
Hiking_Trip.update({"Altitude":"1200m"})
print(f"Updated dictionary : {Hiking_Trip}")
# Out:
# Dictionary : {'location': 'Himalayas', 'difficulty': 'Hard', 'gear': ['Boots', 'Stick'], 'days': 5, 'guide': {'name': 'Sherpa', 'exp': '20y'}}
# ------------------------------------------------------------
# Updated dictionary : {'location': 'Himalayas', 'difficulty': 'Hard', 'gear': ['Boots', 'Stick'], 'days': 5, 'guide': {'name': 'Sherpa', 'exp': '20y'}, 'Altitude': '1200m'}

# %%
Airline_Ticket = {
    "pnr": "XY99", 
    "from": "BOM", 
    "stops": ["DXB", "LHR"], 
    "airline": "Emirates", 
    "seat": {"row": 12, "pos": "Window"}
    }

print(f"Dictionary : {Airline_Ticket}")
print("--"*30)
Airline_Ticket.update({"plan change":2})
print(f"Updated dictionary : {Airline_Ticket}")
# Out:
# Dictionary : {'pnr': 'XY99', 'from': 'BOM', 'stops': ['DXB', 'LHR'], 'airline': 'Emirates', 'seat': {'row': 12, 'pos': 'Window'}}
# ------------------------------------------------------------
# Updated dictionary : {'pnr': 'XY99', 'from': 'BOM', 'stops': ['DXB', 'LHR'], 'airline': 'Emirates', 'seat': {'row': 12, 'pos': 'Window'}, 'plan change': 2}

# %%
Student_ID= {
    "name": "Sayali", 
    "id": 55, 
    "subjects": ["Math", "Python"], 
    "grade": "A", 
    "emergency": {"contact": "999", "name": "Dad"}
    }
print(f"Dictionary : {Student_ID}")
print("--"*30)
Student_ID.update({"Percentage":90.45}) 
print(f"Updated dictionary:{Student_ID}")
# Out:
# Dictionary : {'name': 'Sayali', 'id': 55, 'subjects': ['Math', 'Python'], 'grade': 'A', 'emergency': {'contact': '999', 'name': 'Dad'}}
# ------------------------------------------------------------
# Updated dictionary:{'name': 'Sayali', 'id': 55, 'subjects': ['Math', 'Python'], 'grade': 'A', 'emergency': {'contact': '999', 'name': 'Dad'}, 'Percentage': 90.45}

# %%
Online_Course = {
    "title": "DS 101", 
    "lessons": 45, 
    "topics": ["Loops", "Dicts"], 
    "instructor": "Rahul Sir", 
    "access": {"lifetime": True, "offline": False}
    }
print(f"Dictionary : {Online_Course}")
print("--"*30)
Online_Course.update({"Source":{"Google":"samingerindf.com","Youtube":"Tom's Guide"}})
print(f"Updated dictionary : {Online_Course}")
# Out:
# Dictionary : {'title': 'DS 101', 'lessons': 45, 'topics': ['Loops', 'Dicts'], 'instructor': 'Rahul Sir', 'access': {'lifetime': True, 'offline': False}}
# ------------------------------------------------------------
# Updated dictionary : {'title': 'DS 101', 'lessons': 45, 'topics': ['Loops', 'Dicts'], 'instructor': 'Rahul Sir', 'access': {'lifetime': True, 'offline': False}, 'Source': {'Google': 'samingerindf.com', 'Youtube': "Tom's Guide"}}

# %%
Research_Paper = {
    "title": "AI Growth", 
    "authors": ["Dr. A", "Prof. B"], 
    "citations": 120, 
    "is_published": True, 
    "journal": {"name": "Nature", "vol": 12}
    }
print(f"Dictionary : {Research_Paper}")
print("--"*30)
Research_Paper.update({"Supervisor":"Dr.Dhabe"})
print(f"Updated dictionary :{Research_Paper}")
# Out:
# Dictionary : {'title': 'AI Growth', 'authors': ['Dr. A', 'Prof. B'], 'citations': 120, 'is_published': True, 'journal': {'name': 'Nature', 'vol': 12}}
# ------------------------------------------------------------
# Updated dictionary :{'title': 'AI Growth', 'authors': ['Dr. A', 'Prof. B'], 'citations': 120, 'is_published': True, 'journal': {'name': 'Nature', 'vol': 12}, 'Supervisor': 'Dr.Dhabe'}

# %%
Fruit_Basket = {
    "origin": "Farm-X", 
    "weight": "2kg", 
    "fruits": ["Apple", "Mango", "Pear"], 
    "is_fresh": True, 
    "price_info": {"unit": "kg", "rate": 150}
    }
print(f"Dictionary : {Fruit_Basket}")
print("--"*30)
Fruit_Basket.update({"price":[150,200,100]})
print(f"Updated dictionary :{Fruit_Basket}")
# Out:
# Dictionary : {'origin': 'Farm-X', 'weight': '2kg', 'fruits': ['Apple', 'Mango', 'Pear'], 'is_fresh': True, 'price_info': {'unit': 'kg', 'rate': 150}}
# ------------------------------------------------------------
# Updated dictionary :{'origin': 'Farm-X', 'weight': '2kg', 'fruits': ['Apple', 'Mango', 'Pear'], 'is_fresh': True, 'price_info': {'unit': 'kg', 'rate': 150}, 'price': [150, 200, 100]}

# %%
Coffee_Shop = {
    "name": "Starbucks",
      "type": "Cafe", 
      "beans": ["Arabica", "Robusta"], 
      "wifi": True, 
      "stats": {"daily_cust": 200, "rating": 4.2}
      }
print(f"Dictionary : {Coffee_Shop}")
print("--"*30)
Coffee_Shop.update({"menu":["Sandwitch","Black Coffee","Tea","Coffee"]})
print(f"Updated dictionary :{Coffee_Shop}")
# Out:
# Dictionary : {'name': 'Starbucks', 'type': 'Cafe', 'beans': ['Arabica', 'Robusta'], 'wifi': True, 'stats': {'daily_cust': 200, 'rating': 4.2}}
# ------------------------------------------------------------
# Updated dictionary :{'name': 'Starbucks', 'type': 'Cafe', 'beans': ['Arabica', 'Robusta'], 'wifi': True, 'stats': {'daily_cust': 200, 'rating': 4.2}, 'menu': ['Sandwitch', 'Black Coffee', 'Tea', 'Coffee']}

# %%
Wine_Cellar = {
    "label": "Merlot", 
    "year": 2015, 
    "region": "Napa", 
    "grapes": ["Merlot", "Syrah"], 
    "storage": {"temp": "12C", "shelf": "B1"}
    }
print(f"Dictionary : {Wine_Cellar}")
print("--"*30)
Wine_Cellar.update({"stored duration":11})
print(f"Updated dictionary :{Wine_Cellar}")
# Out:
# Dictionary : {'label': 'Merlot', 'year': 2015, 'region': 'Napa', 'grapes': ['Merlot', 'Syrah'], 'storage': {'temp': '12C', 'shelf': 'B1'}}
# ------------------------------------------------------------
# Updated dictionary :{'label': 'Merlot', 'year': 2015, 'region': 'Napa', 'grapes': ['Merlot', 'Syrah'], 'storage': {'temp': '12C', 'shelf': 'B1'}, 'stored duration': 11}

# %%
Drone = {
    "model": "DJI Mini", 
    "max_altitude": "4000m", 
    "gps": True, 
    "modes": ["Follow", "Orbit"], 
    "camera": {"res": "12MP", "gimbal": "3-axis"}
    }
print(f"Dictionary : {Drone}")
print("--"*30)
Drone.update({"Size":12*12})
print(f"Updated dictionary :{Drone}")
# Out:
# Dictionary : {'model': 'DJI Mini', 'max_altitude': '4000m', 'gps': True, 'modes': ['Follow', 'Orbit'], 'camera': {'res': '12MP', 'gimbal': '3-axis'}}
# ------------------------------------------------------------
# Updated dictionary :{'model': 'DJI Mini', 'max_altitude': '4000m', 'gps': True, 'modes': ['Follow', 'Orbit'], 'camera': {'res': '12MP', 'gimbal': '3-axis'}, 'Size': 144}
